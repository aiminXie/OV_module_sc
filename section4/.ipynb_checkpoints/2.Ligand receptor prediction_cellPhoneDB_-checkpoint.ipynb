# %%
#.libPaths(c("/home/data/refdir/Rlib","/home/data/t060324/R/x86_64-pc-linux-gnu-library/4.1"))
library(scibet)
library(Seurat)
library(scater)
library(scran)
library(dplyr)
library(Matrix)
library(cowplot)
library(ggplot2)
library(harmony)
rm(list = ls())
gc()
setwd('/home/data/t060324/jobs/aimin/')
# Out:
# Attaching SeuratObject
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
# ...

# %%
mergeData_immune <- readRDS(file = './output/1.sangleCell_pre/OV_mergeData_immune_final.RDS')

# %%
cellType <- as.character(mergeData_immune$cellType)
names(cellType) <- colnames(mergeData_immune)
cell_list <- split(colnames(mergeData_immune),f = cellType)
sampleCell <- lapply(cell_list,function(x){
    if(length(x)<400){
        subsample <- x
    }else{
        subsample <- sample(x = x,size = 400,replace = F)
    }
 return(subsample)
})
sampleCell <- do.call(c,sampleCell)
cellType_sub <- cellType[sampleCell]

# %%
mergeData_immune_sub <- subset(mergeData_immune,cells = sampleCell)

# %%
dim(mergeData_immune_sub)
# Out:
# [1] 47605 13200

# %%
write.table(as.matrix(mergeData_immune_sub@assays$RNA@data), './output/3.cellPhoneDB/cellphonedb_count.txt', sep='\t', quote=F)

# %%
meta_data <- cbind(rownames(mergeData_immune_sub@meta.data), mergeData_immune_sub@meta.data[,'cellType', drop=F])
colnames(meta_data) <- c('cellID','cellType')

# %%
head(meta_data)
# Out:
#                                 cellID                          cellType
# GSM5599229_TCTGCCAGTCCCACGA-1_1 GSM5599229_TCTGCCAGTCCCACGA-1_1 B cell
# GSM5743307_GTAGCTAAGAGTTGAT-1_1 GSM5743307_GTAGCTAAGAGTTGAT-1_1 B cell
# ACACTGAAGTCTCGGC-EOC227_pOme1_1 ACACTGAAGTCTCGGC-EOC227_pOme1_1 B cell
# ACGAGGATCCGCGGTA-1_4_1          ACGAGGATCCGCGGTA-1_4_1          B cell
# GSM5743309_CTGTACCGTCTACATG-1_1 GSM5743309_CTGTACCGTCTACATG-1_1 B cell
# TACAGTGAGGTTACCT-EOC227_pOme1_1 TACAGTGAGGTTACCT-EOC227_pOme1_1 B cell

# %%
write.table(meta_data, './output/3.cellPhoneDB/cellphonedb_meta.txt', sep='\t', quote=F, row.names=F)

# %% [markdown]
# ### run cellPhoneDB for immune cells

# %%
## shell code
conda activate cellphonedb
cd /home/data/t060324/jobs/aimin/output/3.cellPhoneDB
cellphonedb method statistical_analysis cellphonedb_meta.txt cellphonedb_count.txt --counts-data=gene_name
cellphonedb plot dot_plot 
cellphonedb plot heatmap_plot cellphonedb_meta.txt

# %%
mynet <- read.delim('./output/3.cellPhoneDB/out/count_network.txt', check.names = FALSE)

# %%
#library(psych)
#library(qgraph)
library(igraph)
library(tidyverse)
# Out:
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following object is masked from ‘package:scater’:
#
#     normalize
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     union
#
#
# The following object is masked from ‘package:IRanges’:
#
#     union
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     normalize, path, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ tibble  3.1.7     ✔ purrr   0.3.4
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ...

# %%
mypvals <- read.delim("./output/3.cellPhoneDB/out/pvalues.txt", check.names = FALSE)
mymeans <- read.delim("./output/3.cellPhoneDB/out/means.txt", check.names = FALSE)

# %%
# 这些基因list很有意思啊，建议保存
chemokines <- grep("^CXC|CCL|CCR|CX3|XCL|XCR", mymeans$interacting_pair,value = T)
chemokines <- grep("^CXC|CCL|CCR|CX3|XCL|XCR", mymeans$interacting_pair,value = T)
th1 <- grep("IL2|IL12|IL18|IL27|IFNG|IL10|TNF$|TNF |LTA|LTB|STAT1|CCR5|CXCR3|IL12RB1|IFNGR1|TBX21|STAT4", 
            mymeans$interacting_pair,value = T)
th2 <- grep("IL4|IL5|IL25|IL10|IL13|AREG|STAT6|GATA3|IL4R", 
            mymeans$interacting_pair,value = T)
th17 <- grep("IL21|IL22|IL24|IL26|IL17A|IL17A|IL17F|IL17RA|IL10|RORC|RORA|STAT3|CCR4|CCR6|IL23RA|TGFB", 
             mymeans$interacting_pair,value = T)
treg <- grep("IL35|IL10|FOXP3|IL2RA|TGFB", mymeans$interacting_pair,value = T)
costimulatory <- grep("CD86|CD80|CD48|LILRB2|LILRB4|TNF|CD2|ICAM|SLAM|LT[AB]|NECTIN2|CD40|CD70|CD27|CD28|CD58|TSLP|PVR|CD44|CD55|CD[1-9]", 
                      mymeans$interacting_pair,value = T)
coinhibitory <- grep("SIRP|CD47|ICOS|TIGIT|CTLA4|PDCD1|CD274|LAG3|HAVCR|VSIR", 
                     mymeans$interacting_pair,value = T)
SLAMF <- grep("SLAMF", 
                     mymeans$interacting_pair,value = T)
niche <- grep("CSF", mymeans$interacting_pair,value = T)

# %%
lr_network = readRDS(url("https://zenodo.org/record/3260758/files/lr_network.rds"))

# %%
subset(lr_network,from=='IFNG')
# Out:
#   from to     source           database
# 1 IFNG IFNGR2 kegg_cytokines   kegg
# 2 IFNG IFNGR1 kegg_cytokines   kegg
# 3 IFNG IFNGR1 ramilowski_known ramilowski
# 4 IFNG IFNGR2 ramilowski_known ramilowski
# 5 IFNG PTPN6  ppi_lr_go        ppi_prediction_go

# %%
head(mymeans)
# Out:
#   id_cp_interaction interacting_pair
# 1 CPI-CS0A5B6BD7A   12oxoLeukotrieneB4_byPTGR1_LTB4R
# 2 CPI-CS047D9C0D7   LeukotrieneB4_byLTA4H_LTB4R
# 3 CPI-CS04A56D5BE   12oxoLeukotrieneB4_byPTGR1_LTB4R2
# 4 CPI-CS0F5B070C5   LeukotrieneB4_byLTA4H_LTB4R2
# 5 CPI-CS0AFE4D0CB   LeukotrieneB4_byLTA4H_GPR17
# 6 CPI-CS00DCACEEE   LeukotrieneC4_byLTC4S_GPR17
#   partner_a                          partner_b     gene_a gene_b secreted
# 1 complex:12oxoLeukotrieneB4_byPTGR1 simple:Q15722        LTB4R  True
# 2 complex:LeukotrieneB4_byLTA4H      simple:Q15722        LTB4R  True
# 3 complex:12oxoLeukotrieneB4_byPTGR1 simple:Q9NPC1        LTB4R2 True
# 4 complex:LeukotrieneB4_byLTA4H      simple:Q9NPC1        LTB4R2 True
# 5 complex:LeukotrieneB4_byLTA4H      simple:Q13304        GPR17  True
# 6 complex:LeukotrieneC4_byLTC4S      simple:Q13304        GPR17  True
#   receptor_a receptor_b annotation_strategy ⋯ pDC|Plasma cell pDC|Tfh pDC|Th17
# ...

# %%
select_data1 <- mymeans$interacting_pair[mymeans$partner_b %in% unique(cellMarkers$gene)]
select_data2 <- mymeans$interacting_pair[mymeans$gene_a %in% unique(cellMarkers$gene)]

# %%
Top20_list <- readRDS(file = './output/1.sangleCell_pre/Top20_list.RDS')

# %%
chemokines_remove <- grep("CCL4L2|CCL3L3|CCL3L1", 
            mymeans$interacting_pair,value = T)
chemokines_sub <- setdiff(chemokines,chemokines_remove)

# %%
pldf$CC.x <- factor(pldf$CC.x,
                    levels = c('Macro_CXCL10|B cell','Macro_CXCL10|Plasma cell','Macro_CXCL10|pDC','Macro_CXCL10|CD38+NK','Macro_CXCL10|Mature NK','Macro_CXCL10|NK',
                               'Macro_CXCL10|Tfh','Macro_CXCL10|Th17','Macro_CXCL10|Tn','Macro_CXCL10|Treg','Macro_CXCL10|CD8+Te','Macro_CXCL10|CD8+Tem',
                               'Macro_CXCL10|CD8+Tex','Macro_CXCL10|CD8+Tn','Macro_CXCL10|CD8+TpreEx','Macro_CXCL10|ISG+CD8T','Macro_CXCL10|cDC1','Macro_CXCL10|cDC2',
                               'Macro_CXCL10|mast_cell','Macro_CXCL10|Macro_C1QB','Macro_CXCL10|Macro_CCL3L3','Macro_CXCL10|Macro_CXCL10','Macro_CXCL10|Macro_MARCO',
                               'Macro_CXCL10|Macro_MT1H','Macro_CXCL10|Macro_SPP1','Macro_CXCL10|Mono_FCN1',
                               'CD8+Tex|B cell','CD8+Tex|Plasma cell','CD8+Tex|pDC','CD8+Tex|CD38+NK','CD8+Tex|Mature NK','CD8+Tex|NK','CD8+Tex|Tfh','CD8+Tex|Th17','CD8+Tex|Tn','CD8+Tex|Treg',
                               'CD8+Tex|CD8+Te','CD8+Tex|CD8+Tem','CD8+Tex|CD8+Tex','CD8+Tex|CD8+Tn','CD8+Tex|CD8+TpreEx','CD8+Tex|ISG+CD8T','CD8+Tex|cDC1','CD8+Tex|cDC2','CD8+Tex|mast_cell',
                               'CD8+Tex|Macro_C1QB','CD8+Tex|Macro_CCL3L3','CD8+Tex|Macro_CXCL10','CD8+Tex|Macro_MARCO','CD8+Tex|Macro_MT1H','CD8+Tex|Macro_SPP1','CD8+Tex|Mono_FCN1',
                               'Tfh|B cell','Tfh|Plasma cell','Tfh|pDC','Tfh|CD38+NK','Tfh|Mature NK','Tfh|NK','Tfh|Tfh','Tfh|Th17','Tfh|Tn','Tfh|Treg','Tfh|CD8+Te','Tfh|CD8+Tem','Tfh|CD8+Tex','Tfh|CD8+Tn','Tfh|CD8+TpreEx',
                               'Tfh|ISG+CD8T','Tfh|cDC1','Tfh|cDC2','Tfh|mast_cell','Tfh|Macro_C1QB','Tfh|Macro_CCL3L3','Tfh|Macro_CXCL10','Tfh|Macro_MARCO','Tfh|Macro_MT1H','Tfh|Macro_SPP1','Tfh|Mono_FCN1',
                               'B cell|B cell','B cell|CD38+NK','B cell|CD8+Te','B cell|CD8+Tem','B cell|CD8+Tex','B cell|CD8+Tn','B cell|CD8+TpreEx','B cell|ISG+CD8T','B cell|Macro_C1QB',
                               'B cell|Macro_CCL3L3','B cell|Macro_CXCL10','B cell|Macro_MARCO','B cell|Macro_MT1H','B cell|Macro_SPP1','B cell|Mature NK','B cell|Mono_FCN1',
                               'B cell|NK','B cell|Plasma cell','B cell|Tfh','B cell|Th17','B cell|Tn','B cell|Treg','B cell|cDC1','B cell|cDC2','B cell|mast_cell','B cell|pDC','Plasma cell|B cell','Plasma cell|CD38+NK','Plasma cell|CD8+Te','Plasma cell|CD8+Tem','Plasma cell|CD8+Tex','Plasma cell|CD8+Tn','Plasma cell|CD8+TpreEx','Plasma cell|ISG+CD8T','Plasma cell|Macro_C1QB','Plasma cell|Macro_CCL3L3''Plasma cell|Macro_CXCL10','Plasma cell|Macro_MARCO','Plasma cell|Macro_MT1H','Plasma cell|Macro_SPP1','Plasma cell|Mature NK','Plasma cell|Mono_FCN1',
                               'Plasma cell|NK','Plasma cell|Plasma cell','Plasma cell|Tfh','Plasma cell|Th17','Plasma cell|Tn','Plasma cell|Treg','Plasma cell|cDC1','Plasma cell|cDC2','Plasma cell|mast_cell','Plasma cell|pDC'
                              ),
                    labels = c('Macro_CXCL10|B cell','Macro_CXCL10|Plasma cell','Macro_CXCL10|pDC','Macro_CXCL10|CD38+NK','Macro_CXCL10|Mature NK','Macro_CXCL10|NK',
                               'Macro_CXCL10|Tfh','Macro_CXCL10|Th17','Macro_CXCL10|Tn','Macro_CXCL10|Treg','Macro_CXCL10|CD8+Te','Macro_CXCL10|CD8+Tem',
                               'Macro_CXCL10|CD8+Tex','Macro_CXCL10|CD8+Tn','Macro_CXCL10|CD8+TpreEx','Macro_CXCL10|ISG+CD8T','Macro_CXCL10|cDC1','Macro_CXCL10|cDC2',
                               'Macro_CXCL10|mast_cell','Macro_CXCL10|Macro_C1QB','Macro_CXCL10|Macro_CCL3L3','Macro_CXCL10|Macro_CXCL10','Macro_CXCL10|Macro_MARCO',
                               'Macro_CXCL10|Macro_MT1H','Macro_CXCL10|Macro_SPP1','Macro_CXCL10|Mono_FCN1',
                               'CD8+Tex|B cell','CD8+Tex|Plasma cell','CD8+Tex|pDC','CD8+Tex|CD38+NK','CD8+Tex|Mature NK','CD8+Tex|NK','CD8+Tex|Tfh','CD8+Tex|Th17','CD8+Tex|Tn','CD8+Tex|Treg',
                               'CD8+Tex|CD8+Te','CD8+Tex|CD8+Tem','CD8+Tex|CD8+Tex','CD8+Tex|CD8+Tn','CD8+Tex|CD8+TpreEx','CD8+Tex|ISG+CD8T','CD8+Tex|cDC1','CD8+Tex|cDC2','CD8+Tex|mast_cell',
                               'CD8+Tex|Macro_C1QB','CD8+Tex|Macro_CCL3L3','CD8+Tex|Macro_CXCL10','CD8+Tex|Macro_MARCO','CD8+Tex|Macro_MT1H','CD8+Tex|Macro_SPP1','CD8+Tex|Mono_FCN1',
                               'Tfh|B cell','Tfh|Plasma cell','Tfh|pDC','Tfh|CD38+NK','Tfh|Mature NK','Tfh|NK','Tfh|Tfh','Tfh|Th17','Tfh|Tn','Tfh|Treg','Tfh|CD8+Te','Tfh|CD8+Tem','Tfh|CD8+Tex','Tfh|CD8+Tn','Tfh|CD8+TpreEx',
                               'Tfh|ISG+CD8T','Tfh|cDC1','Tfh|cDC2','Tfh|mast_cell','Tfh|Macro_C1QB','Tfh|Macro_CCL3L3','Tfh|Macro_CXCL10','Tfh|Macro_MARCO','Tfh|Macro_MT1H','Tfh|Macro_SPP1','Tfh|Mono_FCN1',
                               'B cell|B cell','B cell|CD38+NK','B cell|CD8+Te','B cell|CD8+Tem','B cell|CD8+Tex','B cell|CD8+Tn','B cell|CD8+TpreEx','B cell|ISG+CD8T','B cell|Macro_C1QB',
                               'B cell|Macro_CCL3L3','B cell|Macro_CXCL10','B cell|Macro_MARCO','B cell|Macro_MT1H','B cell|Macro_SPP1','B cell|Mature NK','B cell|Mono_FCN1',
                               'B cell|NK','B cell|Plasma cell','B cell|Tfh','B cell|Th17','B cell|Tn','B cell|Treg','B cell|cDC1','B cell|cDC2','B cell|mast_cell','B cell|pDC','Plasma cell|B cell','Plasma cell|CD38+NK','Plasma cell|CD8+Te','Plasma cell|CD8+Tem','Plasma cell|CD8+Tex','Plasma cell|CD8+Tn','Plasma cell|CD8+TpreEx','Plasma cell|ISG+CD8T','Plasma cell|Macro_C1QB','Plasma cell|Macro_CCL3L3''Plasma cell|Macro_CXCL10','Plasma cell|Macro_MARCO','Plasma cell|Macro_MT1H','Plasma cell|Macro_SPP1','Plasma cell|Mature NK','Plasma cell|Mono_FCN1',
                               'Plasma cell|NK','Plasma cell|Plasma cell','Plasma cell|Tfh','Plasma cell|Th17','Plasma cell|Tn','Plasma cell|Treg','Plasma cell|cDC1','Plasma cell|cDC2','Plasma cell|mast_cell','Plasma cell|pDC'
                              ))

# %%
mymeans %>% 
dplyr::filter(interacting_pair %in% c(chemokines_sub,'CD27_CD70',th1))%>%
  dplyr::select("interacting_pair",starts_with("Macro_CXCL10"),starts_with("CD8+Tex"),starts_with("Tfh"),starts_with("B cell"),starts_with("Plasma cell"))  %>%  
  reshape2::melt() -> meansdf
colnames(meansdf)<- c("interacting_pair","CC","means")
mypvals %>% 
dplyr::filter(interacting_pair %in% c(chemokines_sub,'CD27_CD70',th1))%>%
  dplyr::select("interacting_pair",starts_with("Macro_CXCL10"),starts_with("CD8+Tex"),starts_with("Tfh"),starts_with("B cell"),starts_with("Plasma cell"))%>%  
  reshape2::melt()-> pvalsdf

colnames(pvalsdf)<- c("interacting_pair","CC","pvals")
pvalsdf$joinlab<- paste0(pvalsdf$interacting_pair,"_",pvalsdf$CC)
meansdf$joinlab<- paste0(meansdf$interacting_pair,"_",meansdf$CC)
pldf <- merge(pvalsdf,meansdf,by = "joinlab")
pldf <- subset(pldf,!grepl(pattern = 'CAF',CC.x))
pldf <- subset(pldf,!grepl(pattern = 'Endo',CC.x))
summary((filter(pldf,means >1))$means)
pldf$CC.x <- factor(pldf$CC.x,
                    levels = c('Macro_CXCL10|B cell','Macro_CXCL10|Plasma cell','Macro_CXCL10|pDC','Macro_CXCL10|CD38+NK','Macro_CXCL10|Mature NK','Macro_CXCL10|NK',
                               'Macro_CXCL10|Tfh','Macro_CXCL10|Th17','Macro_CXCL10|Tn','Macro_CXCL10|Treg','Macro_CXCL10|CD8+Te','Macro_CXCL10|CD8+Tem',
                               'Macro_CXCL10|CD8+Tex','Macro_CXCL10|CD8+Tn','Macro_CXCL10|CD8+TpreEx','Macro_CXCL10|ISG+CD8T','Macro_CXCL10|cDC1','Macro_CXCL10|cDC2',
                               'Macro_CXCL10|mast_cell','Macro_CXCL10|Macro_C1QB','Macro_CXCL10|Macro_CCL3L3','Macro_CXCL10|Macro_CXCL10','Macro_CXCL10|Macro_MARCO',
                               'Macro_CXCL10|Macro_MT1H','Macro_CXCL10|Macro_SPP1','Macro_CXCL10|Mono_FCN1',
                               'CD8+Tex|B cell','CD8+Tex|Plasma cell','CD8+Tex|pDC','CD8+Tex|CD38+NK','CD8+Tex|Mature NK','CD8+Tex|NK','CD8+Tex|Tfh','CD8+Tex|Th17','CD8+Tex|Tn','CD8+Tex|Treg',
                               'CD8+Tex|CD8+Te','CD8+Tex|CD8+Tem','CD8+Tex|CD8+Tex','CD8+Tex|CD8+Tn','CD8+Tex|CD8+TpreEx','CD8+Tex|ISG+CD8T','CD8+Tex|cDC1','CD8+Tex|cDC2','CD8+Tex|mast_cell',
                               'CD8+Tex|Macro_C1QB','CD8+Tex|Macro_CCL3L3','CD8+Tex|Macro_CXCL10','CD8+Tex|Macro_MARCO','CD8+Tex|Macro_MT1H','CD8+Tex|Macro_SPP1','CD8+Tex|Mono_FCN1',
                               'Tfh|B cell','Tfh|Plasma cell','Tfh|pDC','Tfh|CD38+NK','Tfh|Mature NK','Tfh|NK','Tfh|Tfh','Tfh|Th17','Tfh|Tn','Tfh|Treg','Tfh|CD8+Te','Tfh|CD8+Tem','Tfh|CD8+Tex','Tfh|CD8+Tn','Tfh|CD8+TpreEx',
                               'Tfh|ISG+CD8T','Tfh|cDC1','Tfh|cDC2','Tfh|mast_cell','Tfh|Macro_C1QB','Tfh|Macro_CCL3L3','Tfh|Macro_CXCL10','Tfh|Macro_MARCO','Tfh|Macro_MT1H','Tfh|Macro_SPP1','Tfh|Mono_FCN1',
                               'B cell|B cell','B cell|CD38+NK','B cell|CD8+Te','B cell|CD8+Tem','B cell|CD8+Tex','B cell|CD8+Tn','B cell|CD8+TpreEx','B cell|ISG+CD8T','B cell|Macro_C1QB',
                               'B cell|Macro_CCL3L3','B cell|Macro_CXCL10','B cell|Macro_MARCO','B cell|Macro_MT1H','B cell|Macro_SPP1','B cell|Mature NK','B cell|Mono_FCN1',
                               'B cell|NK','B cell|Plasma cell','B cell|Tfh','B cell|Th17','B cell|Tn','B cell|Treg','B cell|cDC1','B cell|cDC2','B cell|mast_cell','B cell|pDC','Plasma cell|B cell','Plasma cell|CD38+NK','Plasma cell|CD8+Te','Plasma cell|CD8+Tem','Plasma cell|CD8+Tex','Plasma cell|CD8+Tn','Plasma cell|CD8+TpreEx','Plasma cell|ISG+CD8T',
                               'Plasma cell|Macro_C1QB','Plasma cell|Macro_CCL3L3','Plasma cell|Macro_CXCL10','Plasma cell|Macro_MARCO','Plasma cell|Macro_MT1H','Plasma cell|Macro_SPP1','Plasma cell|Mature NK','Plasma cell|Mono_FCN1',
                               'Plasma cell|NK','Plasma cell|Plasma cell','Plasma cell|Tfh','Plasma cell|Th17','Plasma cell|Tn','Plasma cell|Treg','Plasma cell|cDC1','Plasma cell|cDC2','Plasma cell|mast_cell','Plasma cell|pDC'
                              ),
                    labels = c('Macro_CXCL10|B cell','Macro_CXCL10|Plasma cell','Macro_CXCL10|pDC','Macro_CXCL10|CD38+NK','Macro_CXCL10|Mature NK','Macro_CXCL10|NK',
                               'Macro_CXCL10|Tfh','Macro_CXCL10|Th17','Macro_CXCL10|Tn','Macro_CXCL10|Treg','Macro_CXCL10|CD8+Te','Macro_CXCL10|CD8+Tem',
                               'Macro_CXCL10|CD8+Tex','Macro_CXCL10|CD8+Tn','Macro_CXCL10|CD8+TpreEx','Macro_CXCL10|ISG+CD8T','Macro_CXCL10|cDC1','Macro_CXCL10|cDC2',
                               'Macro_CXCL10|mast_cell','Macro_CXCL10|Macro_C1QB','Macro_CXCL10|Macro_CCL3L3','Macro_CXCL10|Macro_CXCL10','Macro_CXCL10|Macro_MARCO',
                               'Macro_CXCL10|Macro_MT1H','Macro_CXCL10|Macro_SPP1','Macro_CXCL10|Mono_FCN1',
                               'CD8+Tex|B cell','CD8+Tex|Plasma cell','CD8+Tex|pDC','CD8+Tex|CD38+NK','CD8+Tex|Mature NK','CD8+Tex|NK','CD8+Tex|Tfh','CD8+Tex|Th17','CD8+Tex|Tn','CD8+Tex|Treg',
                               'CD8+Tex|CD8+Te','CD8+Tex|CD8+Tem','CD8+Tex|CD8+Tex','CD8+Tex|CD8+Tn','CD8+Tex|CD8+TpreEx','CD8+Tex|ISG+CD8T','CD8+Tex|cDC1','CD8+Tex|cDC2','CD8+Tex|mast_cell',
                               'CD8+Tex|Macro_C1QB','CD8+Tex|Macro_CCL3L3','CD8+Tex|Macro_CXCL10','CD8+Tex|Macro_MARCO','CD8+Tex|Macro_MT1H','CD8+Tex|Macro_SPP1','CD8+Tex|Mono_FCN1',
                               'Tfh|B cell','Tfh|Plasma cell','Tfh|pDC','Tfh|CD38+NK','Tfh|Mature NK','Tfh|NK','Tfh|Tfh','Tfh|Th17','Tfh|Tn','Tfh|Treg','Tfh|CD8+Te','Tfh|CD8+Tem','Tfh|CD8+Tex','Tfh|CD8+Tn','Tfh|CD8+TpreEx',
                               'Tfh|ISG+CD8T','Tfh|cDC1','Tfh|cDC2','Tfh|mast_cell','Tfh|Macro_C1QB','Tfh|Macro_CCL3L3','Tfh|Macro_CXCL10','Tfh|Macro_MARCO','Tfh|Macro_MT1H','Tfh|Macro_SPP1','Tfh|Mono_FCN1',
                               'B cell|B cell','B cell|CD38+NK','B cell|CD8+Te','B cell|CD8+Tem','B cell|CD8+Tex','B cell|CD8+Tn','B cell|CD8+TpreEx','B cell|ISG+CD8T','B cell|Macro_C1QB',
                               'B cell|Macro_CCL3L3','B cell|Macro_CXCL10','B cell|Macro_MARCO','B cell|Macro_MT1H','B cell|Macro_SPP1','B cell|Mature NK','B cell|Mono_FCN1',
                               'B cell|NK','B cell|Plasma cell','B cell|Tfh','B cell|Th17','B cell|Tn','B cell|Treg','B cell|cDC1','B cell|cDC2','B cell|mast_cell','B cell|pDC','Plasma cell|B cell','Plasma cell|CD38+NK','Plasma cell|CD8+Te','Plasma cell|CD8+Tem','Plasma cell|CD8+Tex','Plasma cell|CD8+Tn','Plasma cell|CD8+TpreEx','Plasma cell|ISG+CD8T',
                               'Plasma cell|Macro_C1QB','Plasma cell|Macro_CCL3L3','Plasma cell|Macro_CXCL10','Plasma cell|Macro_MARCO','Plasma cell|Macro_MT1H','Plasma cell|Macro_SPP1','Plasma cell|Mature NK','Plasma cell|Mono_FCN1',
                               'Plasma cell|NK','Plasma cell|Plasma cell','Plasma cell|Tfh','Plasma cell|Th17','Plasma cell|Tn','Plasma cell|Treg','Plasma cell|cDC1','Plasma cell|cDC2','Plasma cell|mast_cell','Plasma cell|pDC'
                              ))
pldf$group <- sub(pattern = '\\|.+','',x = pldf$CC.x)
options(repr.plot.height =7, repr.plot.width = 15)
p2 <- pldf%>% filter( pvals<0.05 & means>0.5) %>% 
  ggplot(aes(CC.x,interacting_pair.x) )+ 
  geom_point(aes(color=means,size=-log10(pvals+0.0001)) ) +
  scale_size_continuous(range = c(1,5))+facet_grid(. ~ group, scales = "free", space = "free")+
  scale_color_gradient2(high="red",mid = "yellow",low ="darkblue",midpoint = 1.5  )+ theme_bw()+ labs(x = "", y = "")+
  theme(axis.text.x = element_text(angle = -90,hjust = 0,vjust = 0.5),strip.text.x = element_blank(),axis.title = element_text(size = 15)) 
p2
# Out:
# Using interacting_pair as id variables
#
# Using interacting_pair as id variables
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.001   1.135   1.312   1.405   1.490   2.337
# plot without title

# %%
pdf(file = './output/bulk/section_4/2.CellphoneDB_source.pdf',width = 15,height =7)
print(p2)
dev.off()
# Out:
# png
#   2
